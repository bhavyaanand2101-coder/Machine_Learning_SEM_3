# %%
n=[[23,4,5,5],{"dd":[23,"rahul"]}]
# print rahul
print(n[1]["dd"][1])
# replace rahul with rahul kumar
n[1]["dd"][1] = "rahul kumar"
# Out:
# rahul

# %%
n=[[23,4,5,5],{"dd":[23,"rahul"]}]
print(n[1]["dd"][1])
# replace rahul with rahul kumar
n[1]["dd"][1] = "rahul kumar"
print(n[1]["dd"][1])
# Out:
# rahul
# rahul kumar
