# %%
class Demo:
    def __init__(self, a,b):
        self.a = a
        self.b = b
    def sum(self):
        return self.a + self.b
    ab=Demo(10,20)
    print(ab.sum())
# Out:
# 30

# %%
class Demo:
    def __init__(self):
        pass
    def add(self, a,b):
        print("Sum is ", a+b)

# %%
class Largest_No:
    def __init__(self, a, b, c):
        self.a = a
        self.b = b
        self.c = c

    def largest(self):
        print("Largest number is", max(self.a, self.b, self.c))
        


a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))

number = Largest_No(a, b, c)
number.largest()
# Out:
# Largest number is 4

# %%
class Largest_No:
    def __init__(self, a, b, c):
        self.a = a
        self.b = b
        self.c = c
    def largest(self):
        if (self.a >= self.b) and (self.a >= self.c):
            print("Largest number is", self.a)
        elif (self.b >= self.a) and (self.b >= self.c):
            print("Largest number is", self.b)
        else:
            print("Largest number is", self.c)
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))
number = Largest_No(a, b, c)
number.largest()

# %%
class MyLinearRegression:
    def __init__(self,lr=0.1,epoch=1000):
        self.lr = lr
        self.epoch = epoch
        self.m=0
        self.c=0
        def fit(self,x,y):
            for _ in range(self.epoch):
