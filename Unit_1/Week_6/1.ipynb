# %%
n=[("shan",111),("KUAn",123)]
print()
#
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 n=[("shan",111),("KUAn",123)]
# ----> 2 print(datatype(n))
#
# NameError: name 'datatype' is not defined

# %%
n=[(12,["Abhi"],(13,["Amrit",11],(14,["ravi",43])))]
# return in acc of numbers

# %%
n=[221,545,76569,344578,3958835,9228394,456789999]
# filter no whose last digit is 9
